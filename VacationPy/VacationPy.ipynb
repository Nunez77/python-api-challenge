# %% [markdown]
# # VacationPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Otras
# %matplotlib inline

# %%
# Import API key
from llavero import gkey

# %% [markdown]
# # Create a heat map that displays the humidity for every city from Part I.

# %%
# Import Data from las excercise
old_data = "../WeatherPy/weather_df.csv"
cities = pd.read_csv(old_data)
city_data = cities[cities["Cloudiness"] > 0]     # Eliminate rows without data
city_data
# Out:
#       Unnamed: 0                       City  Cloudiness Country          Date  \
# 0              0                   Sisophon        91.0      KH  1.619745e+09
# 1              1              San Cristobal        75.0      VE  1.619745e+09
# 2              2                   Cam Ranh        20.0      VN  1.619745e+09
# 4              4                Yellowknife        75.0      CA  1.619744e+09
# 5              5                       Lebu       100.0      CL  1.619744e+09
# ...          ...                        ...         ...     ...           ...
# 1395        1395                    Rikitea        77.0      PF  1.619744e+09
# 1396        1396                   Sobolevo       100.0      RU  1.619745e+09
# 1397        1397                     Albany       100.0      US  1.619744e+09
# 1398        1398         San Ciro De Acosta        57.0      MX  1.619745e+09
# 1399        1399  Petropavlovsk-Kamchatskiy        20.0      RU  1.619745e+09
#
#       Humidity      Lat       Lon  Hi Temp  Wind Speed
# 0         78.0  13.5859  102.9737    26.92        2.67
# 1        100.0   7.7669  -72.2250    24.00        1.54
# 2         65.0  11.9214  109.1591    29.00        2.06
# 4         59.0  62.4560 -114.3525    -1.11        6.17
# 5         94.0 -37.6167  -73.6500    12.83        3.42
# ...        ...      ...       ...      ...         ...
# 1395      66.0 -23.1203 -134.9692    24.79        5.37
# 1396      86.0  54.4299   31.8996     7.55        5.53
# 1397      90.0  42.6001  -73.9662    12.78        0.45
# 1398      69.0  21.6333  -99.8167    26.80        8.71
# 1399      61.0  53.0452  158.6483     9.00        3.00
#
# [1157 rows x 10 columns]

# %%
# Create a Humidity Heatmap Layer
loc_hm = city_data[['Lat','Lon']].astype(float)
loc_hm.head()
# Out:
#        Lat       Lon
# 0  13.5859  102.9737
# 1   7.7669  -72.2250
# 2  11.9214  109.1591
# 4  62.4560 -114.3525
# 5 -37.6167  -73.6500

# %%
# Create a Humidity Heatmap Layer
hum_hm = city_data["Humidity"].astype(float)
hum_df = pd.DataFrame(hum_hm)
hum_df.head()
# Out:
#    Humidity
# 0      78.0
# 1     100.0
# 2      65.0
# 4      59.0
# 5      94.0

# %%
# Plot Heatmap
figure_layout = {
    'width': '1000px',
    'height': '800px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}


fig = gmaps.figure(layout=figure_layout, zoom_level=2, center=((28,2)))

 
heat_layer = gmaps.heatmap_layer(loc_hm, weights=hum_hm, 
                                 dissipating=False, max_intensity=100, point_radius=3)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# Select criteria to map
# A max temperature lower than 25 degrees Celsius but higher than 18 degrees Celsius.
# Wind speed less than 10 km/h.
# Zero cloudiness.
mycities = city_data
mycities = mycities[mycities['Hi Temp'] <= 25]
mycities = mycities[mycities['Hi Temp'] > 18]
mycities = mycities[mycities['Wind Speed'] <= 16]
mycities = mycities[mycities['Cloudiness'] <= 25]
mycities.head()
# Out:
#     Unnamed: 0             City  Cloudiness Country          Date  Humidity  \
# 11          11      New Norfolk         8.0      AU  1.619745e+09      64.0
# 28          28         Siavonga        22.0      ZM  1.619745e+09      67.0
# 52          52  Arraial Do Cabo         9.0      BR  1.619744e+09      72.0
# 55          55      New Norfolk         8.0      AU  1.619745e+09      64.0
# 57          57        Bathsheba        20.0      BB  1.619745e+09      65.0
#
#         Lat       Lon  Hi Temp  Wind Speed
# 11 -42.7826  147.0587    18.33        2.24
# 28 -16.5382   28.7088    22.49        1.85
# 52 -22.9661  -42.0278    22.14        4.19
# 55 -42.7826  147.0587    18.33        2.24
# 57  13.2167  -59.5167    25.00        7.72

# %% [markdown]
# * Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.
# * Plot the hotels on top of the humidity heatmap with each pin containing the Hotel Name, City, and Country.

# %% [markdown]
# Hotel Map
#
# * Store into variable named hotel_df.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = mycities
hotel_df["Hotel"] = ""
hotel_df
# Out:
#       Unnamed: 0             City  Cloudiness Country          Date  Humidity  \
# 11            11      New Norfolk         8.0      AU  1.619745e+09      64.0
# 28            28         Siavonga        22.0      ZM  1.619745e+09      67.0
# 52            52  Arraial Do Cabo         9.0      BR  1.619744e+09      72.0
# 55            55      New Norfolk         8.0      AU  1.619745e+09      64.0
# 57            57        Bathsheba        20.0      BB  1.619745e+09      65.0
# ...          ...              ...         ...     ...           ...       ...
# 1331        1331           Hobart        20.0      AU  1.619745e+09      77.0
# 1344        1344           Lompoc         8.0      US  1.619745e+09      77.0
# 1354        1354           Hobart        20.0      AU  1.619745e+09      77.0
# 1358        1358             Hami         3.0      CN  1.619745e+09      15.0
# 1378        1378           Touros        20.0      BR  1.619745e+09      94.0
#
#           Lat       Lon  Hi Temp  Wind Speed Hotel
# 11   -42.7826  147.0587    18.33        2.24
# 28   -16.5382   28.7088    22.49        1.85
# 52   -22.9661  -42.0278    22.14        4.19
# 55   -42.7826  147.0587    18.33        2.24
# 57    13.2167  -59.5167    25.00        7.72
# ...       ...       ...      ...         ...   ...
# 1331 -42.8794  147.3294    18.33        4.12
# 1344  34.6391 -120.4579    18.89        5.66
# 1354 -42.8794  147.3294    18.33        4.12
# 1358  42.8000   93.4500    21.77        3.76
# 1378  -5.1989  -35.4608    24.00        3.09
#
# [123 rows x 11 columns]

# %%
# Look for nearby hotels in the selected regions
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
hotel_per_city = hotel_df[['City','Lat','Lon']]
hotel = []
for index, row in hotel_per_city.iterrows():
    lats = hotel_per_city['Lat'][index]
    lngs = hotel_per_city['Lon'][index]
    params = {
        "location": f"{lats},{lngs}",  
        "rankby": "distance",
        "keyword": "hotel",
        "key": gkey,}
    response = requests.get(base_url, params=params).json()
    try:
        results = response['results']
        hotel.append(results[0]['name'])
    except:
        hotel_df = hotel_df.drop(index)
hotel
# Out:
# ['Claremont House',
#  'Lavongora Waterfront Lodge',
#  'Pousada Central',
#  'Claremont House',
#  'ECO Lifestyle & Lodge',
#  'Claremont House',
#  'Vibe Hotel Hobart',
#  'Pousada Central',
#  'Claremont House',
#  'Claremont House',
#  'Hotel El Descanso del Guía',
#  'Vibe Hotel Hobart',
#  '鵜原館',
#  "O'Cairns Inn & Suites",
#  'Claremont House',
#  'Claremont House',
#  'Hotel El Descanso del Guía',
#  'Hotel El Descanso del Guía',
#  'Gandalf Safari Camp',
#  'Pousada Central',
#  'Claremont House',
#  'Estancia Real Los Cabos',
#  'Pousada Central',
#  'The Marshall Suites',
#  'Hotel El Descanso del Guía',
#  'Vibe Hotel Hobart',
#  'Estancia Real Los Cabos',
#  'Pousada Central',
#  'Havelock Inn & Suites',
#  'Le Terre Sainte',
#  'ECO Lifestyle & Lodge',
#  'Claremont House',
#  'Pousada Central',
#  '鵜原館',
#  'Vibe Hotel Hobart',
#  'Estancia Real Los Cabos',
#  'Hospedaje Makoto',
#  'Pousada Central',
#  'Hotel Loma Dorada',
#  'Vibe Hotel Hobart',
#  'Pousada Alecrim Namrau',
#  'Martini Dar Zamaria',
#  'Havelock Inn & Suites',
#  'Hotel El Descanso del Guía',
#  'Claremont House',
#  'Pousada Central',
#  'Estancia Real Los Cabos',
#  '大新旅館',
#  'Colonial Inn - Ft. Benning',
#  'Hotel El Descanso del Guía',
#  'Pousada Central',
#  'Claremont House',
#  'Vibe Hotel Hobart',
#  '大新旅館',
#  "O'Cairns Inn & Suites",
#  'Pousada Central',
#  'Hotel El Descanso del Guía',
#  'Coach House Hotel-Motel',
#  'Gandalf Safari Camp',
#  'Vibe Hotel Hobart',
#  'Vibe Hotel Hobart',
#  'Kim Long Hotel',
#  'Pousada Central',
#  'Vibe Hotel Hobart',
#  'Havelock Inn & Suites',
#  'Pousada Central',
#  'Hotel 385',
#  'Claremont House',
#  'Estancia Real Los Cabos',
#  'Vibe Hotel Hobart',
#  'Claremont House',
#  'Vibe Hotel Hobart',
#  'Vibe Hotel Hobart',
#  'Pousada Central',
#  'Vibe Hotel Hobart',
#  'Hotel Loma Dorada',
#  'Pousada Alecrim Namrau',
#  'Ahipara Holiday Park',
#  'Colonial Inn - Ft. Benning',
#  'Pousada Central',
#  'Vibe Hotel Hobart',
#  'Pousada Central',
#  'Claremont House',
#  'Port Stephens Motel',
#  'Hotel El Descanso del Guía',
#  'Vibe Hotel Hobart',
#  'ECO Lifestyle & Lodge',
#  'Pousada Central',
#  'Pousada Alecrim Namrau',
#  'Le Muse - Bed & Breakfast',
#  'Claremont House',
#  'Shimoda Itoen Hotel Hanamisaki',
#  'Claremont House',
#  'Vibe Hotel Hobart',
#  'Vibe Hotel Hobart',
#  'Pousada Central',
#  'Urban Suites',
#  'Vibe Hotel Hobart',
#  'Vibe Hotel Hobart',
#  'Pousada Central',
#  'Vibe Hotel Hobart',
#  "O'Cairns Inn & Suites",
#  'Estancia Real Los Cabos',
#  "O'Cairns Inn & Suites",
#  'Pousada Central',
#  'Hotel El Descanso del Guía',
#  'Hotel El Descanso del Guía',
#  'Hotel El Descanso del Guía',
#  'Pousada Alecrim Namrau',
#  'Hotel El Descanso del Guía',
#  'Port Stephens Motel',
#  'Pousada Central',
#  'Vibe Hotel Hobart',
#  'Vibe Hotel Hobart',
#  'Vibe Hotel Hobart',
#  'Coin de Mire Attitude Hotel',
#  'Vibe Hotel Hobart',
#  "O'Cairns Inn & Suites",
#  'Vibe Hotel Hobart',
#  'Sunshine Hotel & Resort',
#  'Bugaendrus Paradise']

# %%
# Integrate hotel list to column in dataframe
hotel_df = pd.DataFrame(hotel_df)
hotel_df['Hotel Name'] = hotel
hotel_df
# Out:
#       Unnamed: 0             City  Cloudiness Country          Date  Humidity  \
# 11            11      New Norfolk         8.0      AU  1.619745e+09      64.0
# 28            28         Siavonga        22.0      ZM  1.619745e+09      67.0
# 52            52  Arraial Do Cabo         9.0      BR  1.619744e+09      72.0
# 55            55      New Norfolk         8.0      AU  1.619745e+09      64.0
# 57            57        Bathsheba        20.0      BB  1.619745e+09      65.0
# ...          ...              ...         ...     ...           ...       ...
# 1331        1331           Hobart        20.0      AU  1.619745e+09      77.0
# 1344        1344           Lompoc         8.0      US  1.619745e+09      77.0
# 1354        1354           Hobart        20.0      AU  1.619745e+09      77.0
# 1358        1358             Hami         3.0      CN  1.619745e+09      15.0
# 1378        1378           Touros        20.0      BR  1.619745e+09      94.0
#
#           Lat       Lon  Hi Temp  Wind Speed Hotel                  Hotel Name
# 11   -42.7826  147.0587    18.33        2.24                   Claremont House
# 28   -16.5382   28.7088    22.49        1.85        Lavongora Waterfront Lodge
# 52   -22.9661  -42.0278    22.14        4.19                   Pousada Central
# 55   -42.7826  147.0587    18.33        2.24                   Claremont House
# 57    13.2167  -59.5167    25.00        7.72             ECO Lifestyle & Lodge
# ...       ...       ...      ...         ...   ...                         ...
# 1331 -42.8794  147.3294    18.33        4.12                 Vibe Hotel Hobart
# 1344  34.6391 -120.4579    18.89        5.66             O'Cairns Inn & Suites
# 1354 -42.8794  147.3294    18.33        4.12                 Vibe Hotel Hobart
# 1358  42.8000   93.4500    21.77        3.76           Sunshine Hotel & Resort
# 1378  -5.1989  -35.4608    24.00        3.09               Bugaendrus Paradise
#
# [121 rows x 12 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[['Lat', 'Lon']]

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
